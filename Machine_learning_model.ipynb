# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#import graphviz <-------------- 圖示化決策樹的
from sklearn import ensemble , preprocessing , metrics , svm , tree , linear_model   
from sklearn.neural_network import MLPClassifier
#from keras.utils import np_utils
#from keras.models import Sequential
#from keras.layers import Dense, Activation ,Dropout
#from keras.optimizers import RMSprop ,Adam

# %% [markdown]
# ## load data

# %%
data = pd.read_csv("C:\\Users\\USER\\github\\E.sun_conpetition\\data_set\\new_clean_data.csv")

# %%
data.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'building_id',
#  'building_material',
#  'city',
#  'txn_dt',
#  'total_floor',
#  'building_type',
#  'building_use',
#  'building_complete_dt',
#  'parking_way',
#  'parking_area',
#  'parking_price',
#  'txn_floor',
#  'land_area',
#  'building_area',
#  'town',
#  'lat',
#  'lon',
#  'village_income_median',
#  'town_population',
#  'town_area',
#  'town_population_density',
#  'doc_Rate',
#  'master_rate',
#  'bachelor_rate',
#  'jobschool_rate',
#  'highschool_rate',
#  'junior_rate',
#  'elementary_rate',
#  'born_rate',
#  'death_date',
#  'marriage_rate',
#  'divorce_rate',
#  'village',
#  'N_50',
#  'N_500',
#  'N_1000',
#  'N_5000',
#  'N_10000',
#  'I_10',
#  'I_50',
#  'I_index_50',
#  'I_100',
#  'I_250',
#  'I_500',
#  'I_index_500',
#  'I_1000',
#  'I_index_1000',
#  'I_5000',
#  'I_10000',
#  'I_MIN',
#  'II_10',
#  'II_50',
#  'II_index_50',
#  'II_100',
#  'II_250',
#  'II_500',
#  'II_index_500',
#  'II_1000',
#  'II_index_1000',
#  'II_5000',
# ...

# %%
model <<---- fit 好的

# %%
model.predict()

# %%
datatest = pd.read_csv("C:\\Users\\USER\\github\\E.sun_conpetition\\data_set\\test.csv")

# %%
datatest
# Out:
#            building_id  building_material  city  txn_dt  total_floor  \
# 0     X5gsdTWGS3W7JJQB                  1    13   18634            2
# 1     BTshNOJyKHnT2YIT                  8     7   20199           10
# 2     dhdymr0lV8N5kZOT                  8    12   19769            4
# 3     VEwyGGMcD56w5BOc                 10     7   20479           19
# 4     wmUeMoJZfsqaSX9b                  8     3   18164           13
# 5     EtBjGAHmHCe9t7TZ                  8    12   18632            4
# 6     hPNH34vmaZtvBtqc                  8     7   19144           14
# 7     wXjeI38bYDMJJwZC                  8    13   19452            5
# 8     fxZSGX6aPAFKU8W4                  1    17   19045            2
# 9     ewr0Fx6ign87OwaV                  8     7   19220           13
# 10    gHKurnEP4AowzsLg                  8    10   20045            5
# 11    PmLfTgY2FElLrTl0                  8     7   18222            5
# 12    eM2NppIOwzW0o8iy                  8     7   20614           14
# ...

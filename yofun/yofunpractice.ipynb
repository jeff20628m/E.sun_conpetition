# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 資料讀取

# %%
train=pd.read_csv("C:/Users/yofun/Documents/dataset-0510/train.csv")

# %%
test=pd.read_csv("C:/Users/yofun/Documents/dataset-0510/test.csv")

# %%
train.shape
# Out:
# (60000, 235)

# %%
train.head()
# Out:
#         building_id  building_material  city  txn_dt  total_floor  \
# 0  e3mMIMR3JJqCaXz1                  8    21   18674            4
# 1  LgwzgklNvy4QCtq5                  8     7   18800            5
# 2  ucIR2NLLsC3T650L                  8     7   19289            4
# 3  jre1pJhcQj91Kdky                  8    21   20385           24
# 4  rQpYpY9nRG7X5mmr                  1    21   20657            2
#
#    building_type  building_use  building_complete_dt  parking_way  \
# 0              3             2                  6271            2
# 1              1             2                  7885            2
# 2              1             2                  6028            2
# 3              0             2                 18325            0
# 4              4             2                  6880            2
#
#    parking_area  ...  XIV_500  XIV_index_500  XIV_1000  XIV_index_1000  \
# 0           NaN  ...       58              1       157               1
# ...

# %%
train.columns
# Out:
# Index(['building_id', 'building_material', 'city', 'txn_dt', 'total_floor',
#        'building_type', 'building_use', 'building_complete_dt', 'parking_way',
#        'parking_area',
#        ...
#        'XIV_500', 'XIV_index_500', 'XIV_1000', 'XIV_index_1000', 'XIV_5000',
#        'XIV_index_5000', 'XIV_10000', 'XIV_index_10000', 'XIV_MIN',
#        'total_price'],
#       dtype='object', length=235)

# %% [markdown]
# # 找NA值

# %% [markdown]
# ## 找train NA

# %%
train_col = train.columns.tolist()

# %%
train_col
# Out:
# ['building_id',
#  'building_material',
#  'city',
#  'txn_dt',
#  'total_floor',
#  'building_type',
#  'building_use',
#  'building_complete_dt',
#  'parking_way',
#  'parking_area',
#  'parking_price',
#  'txn_floor',
#  'land_area',
#  'building_area',
#  'town',
#  'lat',
#  'lon',
#  'village_income_median',
#  'town_population',
#  'town_area',
#  'town_population_density',
#  'doc_rate',
#  'master_rate',
#  'bachelor_rate',
#  'jobschool_rate',
#  'highschool_rate',
#  'junior_rate',
#  'elementary_rate',
#  'born_rate',
#  'death_rate',
#  'marriage_rate',
#  'divorce_rate',
#  'village',
#  'N_50',
#  'N_500',
#  'N_1000',
#  'N_5000',
#  'N_10000',
#  'I_10',
#  'I_50',
#  'I_index_50',
#  'I_100',
#  'I_250',
#  'I_500',
#  'I_index_500',
#  'I_1000',
#  'I_index_1000',
#  'I_5000',
#  'I_index_5000',
#  'I_10000',
#  'I_index_10000',
#  'I_MIN',
#  'II_10',
#  'II_50',
#  'II_index_50',
#  'II_100',
#  'II_250',
#  'II_500',
#  'II_index_500',
#  'II_1000',
# ...

# %%
train_no_NA = train.dropna(axis=1)

# %%
train_no_NA
# Out:
#             building_id  building_material  city  txn_dt  total_floor  \
# 0      e3mMIMR3JJqCaXz1                  8    21   18674            4
# 1      LgwzgklNvy4QCtq5                  8     7   18800            5
# 2      ucIR2NLLsC3T650L                  8     7   19289            4
# 3      jre1pJhcQj91Kdky                  8    21   20385           24
# 4      rQpYpY9nRG7X5mmr                  1    21   20657            2
# 5      HmW2MkrwafmceWAH                  8    21   18394            5
# 6      ITYyim3zx6DQyCoF                  8     7   20474           15
# 7      KFrxqaWZaLynrOae                  8    12   18185            8
# 8      ZiK0gY7A0BvwZ8OV                  8    21   18794            5
# 9      QnytA7FbgaVxIDuP                  8     7   19927           10
# 10     jcbuA8q3KPH9SzpS                  1     7   18333            2
# 11     KHo10f3pvTcVL7Dc                  8    21   18184            5
# ...

# %%
train_noNA_col = train_no_NA.columns.tolist()

# %%
train_noNA_col
# Out:
# ['building_id',
#  'building_material',
#  'city',
#  'txn_dt',
#  'total_floor',
#  'building_type',
#  'building_use',
#  'building_complete_dt',
#  'parking_way',
#  'land_area',
#  'building_area',
#  'town',
#  'lat',
#  'lon',
#  'town_population',
#  'town_area',
#  'town_population_density',
#  'doc_rate',
#  'master_rate',
#  'bachelor_rate',
#  'jobschool_rate',
#  'highschool_rate',
#  'junior_rate',
#  'elementary_rate',
#  'born_rate',
#  'death_rate',
#  'marriage_rate',
#  'divorce_rate',
#  'village',
#  'N_50',
#  'N_500',
#  'N_1000',
#  'N_5000',
#  'N_10000',
#  'I_10',
#  'I_50',
#  'I_index_50',
#  'I_100',
#  'I_250',
#  'I_500',
#  'I_index_500',
#  'I_1000',
#  'I_index_1000',
#  'I_5000',
#  'I_index_5000',
#  'I_10000',
#  'I_index_10000',
#  'I_MIN',
#  'II_10',
#  'II_50',
#  'II_index_50',
#  'II_100',
#  'II_250',
#  'II_500',
#  'II_index_500',
#  'II_1000',
#  'II_index_1000',
#  'II_5000',
#  'II_index_5000',
#  'II_10000',
#  'II_index_10000',
# ...

# %%
na_set = set(train_col) - set(train_noNA_col)

# %%
na_set
# Out:
# {'parking_area', 'parking_price', 'txn_floor', 'village_income_median'}

# %%
with_na = list(na_set)

# %%
with_na
# Out:
# ['txn_floor', 'parking_area', 'parking_price', 'village_income_median']

# %% [markdown]
# ## test

# %%
test_col = test.columns.tolist()
test_no_NA = test.dropna(axis=1)
test_noNA_col = test_no_NA.columns.tolist()

# %%
na_set_test = set(test_col) - set(test_noNA_col)
with_na_test = list(na_set_test)

# %%
with_na_test
# Out:
# ['txn_floor', 'parking_area', 'parking_price', 'village_income_median']

# %% [markdown]
# # fill NA

# %% [markdown]
# ## training data

# %%
train_na_list=train[na_set]

# %%
train_na_list
# Out:
#        txn_floor  parking_area  parking_price  village_income_median
# 0            3.0           NaN            NaN                  572.0
# 1            5.0           NaN            NaN                  550.0
# 2            1.0           NaN            NaN                  625.0
# 3           13.0           NaN   81138.889760                  950.0
# 4            NaN           NaN            NaN                  536.0
# 5            4.0           NaN            NaN                  561.0
# 6            8.0           NaN   61488.568950                  716.0
# 7            4.0           NaN    6721.823057                  618.0
# 8            1.0           NaN            NaN                  513.0
# 9            2.0           NaN   61488.568950                  604.0
# 10           NaN           NaN            NaN                  560.0
# 11           NaN           NaN            NaN                  950.0
# 12           7.0           NaN            NaN                  595.0
# ...

# %%
train_na_list.describe()
# Out:
#           txn_floor  parking_area  parking_price  village_income_median
# count  44098.000000   3103.000000   1.393500e+04           58858.000000
# mean       5.389269      7.211837   5.025058e+04             674.840175
# std        3.944618     20.453902   3.973488e+04             140.653083
# min        1.000000      0.000000   0.000000e+00             411.000000
# 25%        3.000000      3.738412   2.827238e+04             583.000000
# 50%        4.000000      5.758023   4.379195e+04             642.000000
# 75%        7.000000      7.180619   6.148857e+04             729.000000
# max       28.000000    967.370868   1.020404e+06            1851.000000

# %%
train["txn_floor"] = train["txn_floor"].fillna(train["txn_floor"].mean())

# %%
train["txn_floor"].describe()
# Out:
# count    60000.000000
# mean         5.389269
# std          3.381719
# min          1.000000
# 25%          3.000000
# 50%          5.389269
# 75%          6.000000
# max         28.000000
# Name: txn_floor, dtype: float64

# %%
train["parking_area"] = train["parking_area"].fillna(0)

# %%
train["parking_area"].describe()
# Out:
# count    60000.000000
# mean         0.372972
# std          4.917360
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        967.370868
# Name: parking_area, dtype: float64

# %%
train["parking_price"] = train["parking_price"].fillna(0)

# %%
train["parking_price"].describe()
# Out:
# count    6.000000e+04
# mean     1.167070e+04
# std      2.858202e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.020404e+06
# Name: parking_price, dtype: float64

# %%
train["village_income_median"] = train["village_income_median"].fillna(train["village_income_median"].median())

# %%
train["village_income_median"].describe()
# Out:
# count    60000.000000
# mean       674.215117
# std        139.380337
# min        411.000000
# 25%        584.000000
# 50%        642.000000
# 75%        728.000000
# max       1851.000000
# Name: village_income_median, dtype: float64

# %%
train_na_list.describe()
# Out:
#           txn_floor  parking_area  parking_price  village_income_median
# count  44098.000000   3103.000000   1.393500e+04           58858.000000
# mean       5.389269      7.211837   5.025058e+04             674.840175
# std        3.944618     20.453902   3.973488e+04             140.653083
# min        1.000000      0.000000   0.000000e+00             411.000000
# 25%        3.000000      3.738412   2.827238e+04             583.000000
# 50%        4.000000      5.758023   4.379195e+04             642.000000
# 75%        7.000000      7.180619   6.148857e+04             729.000000
# max       28.000000    967.370868   1.020404e+06            1851.000000

# %%
train[train_na_list.columns].describe()
# Out:
#           txn_floor  parking_area  parking_price  village_income_median
# count  60000.000000  60000.000000   6.000000e+04           60000.000000
# mean       5.389269      0.372972   1.167070e+04             674.215117
# std        3.381719      4.917360   2.858202e+04             139.380337
# min        1.000000      0.000000   0.000000e+00             411.000000
# 25%        3.000000      0.000000   0.000000e+00             584.000000
# 50%        5.389269      0.000000   0.000000e+00             642.000000
# 75%        6.000000      0.000000   0.000000e+00             728.000000
# max       28.000000    967.370868   1.020404e+06            1851.000000

# %%
train
# Out:
#             building_id  building_material  city  txn_dt  total_floor  \
# 0      e3mMIMR3JJqCaXz1                  8    21   18674            4
# 1      LgwzgklNvy4QCtq5                  8     7   18800            5
# 2      ucIR2NLLsC3T650L                  8     7   19289            4
# 3      jre1pJhcQj91Kdky                  8    21   20385           24
# 4      rQpYpY9nRG7X5mmr                  1    21   20657            2
# 5      HmW2MkrwafmceWAH                  8    21   18394            5
# 6      ITYyim3zx6DQyCoF                  8     7   20474           15
# 7      KFrxqaWZaLynrOae                  8    12   18185            8
# 8      ZiK0gY7A0BvwZ8OV                  8    21   18794            5
# 9      QnytA7FbgaVxIDuP                  8     7   19927           10
# 10     jcbuA8q3KPH9SzpS                  1     7   18333            2
# 11     KHo10f3pvTcVL7Dc                  8    21   18184            5
# ...

# %%
train_list_dummy = ["building_material", 'city', 'building_type', 'building_use', 'parking_way', 'town', 'village']

# %%
dum_mat = pd.get_dummies(train["building_material"], prefix='mat')

# %%
a = pd.DataFrame()
b = []
for i  in train_list_dummy :
    #store = pd.get_dummies(train[i], prefix=i)
    #store1 = pd.concat([a,store],axis=1)
    #a = store1
    b.append( pd.get_dummies(train[i], prefix=i))

# %%
c =pd.concat(b,axis=1)

train_full = pd.concat([train,c],axis=1)

# %%
train_full.drop(train_list_dummy, axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
#import graphviz
from sklearn.tree import DecisionTreeRegressor

# %%
trainy= train_full['total_price']

# %%
train_full.drop('building_id',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-51e60856c238> in <module>
# ----> 1 train_full.drop(['building_id','total_price'],axis=1,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
train_full.drop('total_price',axis=1,inplace=True)

# %%
trainX , testX , train_y , test_y = train_test_split (train_full , trainy , test_size = 0.3)

# %%
treereg = DecisionTreeRegressor()

# %%
cross_val_score(treereg,train_full,trainy,cv=10)
# Out:
# array([0.59520422, 0.63075173, 0.73254681, 0.81898905, 0.9500879 ,
#        0.87751198, 0.4127967 , 0.78408319, 0.71000827, 0.91699042])

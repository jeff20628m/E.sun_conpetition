# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#import graphviz
from sklearn import ensemble , preprocessing , metrics , svm , tree , linear_model
from sklearn.neural_network import MLPClassifier
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation ,Dropout
from keras.optimizers import RMSprop ,Adam
# Out:
# Using TensorFlow backend.

# %%
data_novill = pd.read_csv('C:\\Users\\USER\\github\\E.sun_conpetition\\data_set\\dummy_data_novill.csv')
data =  pd.read_csv('C:\\Users\\USER\\github\\E.sun_conpetition\\data_set\\dummy_data.csv')
train_y =  pd.read_csv('C:\\Users\\USER\\github\\E.sun_conpetition\\data_set\\train_y.csv')

# %%
data_novill = data_novill.iloc[:,2:]
data = data.iloc[:,2:]
train_y = train_y.iloc[:,1]

# %% [markdown]
# # normalization :
#
# # formula : L1 normalization =  $$  \frac{df - df(mean)}  {df(std)} $$

# %%
data_novill_norm = (data_novill - data_novill.mean()) / data_novill.std()

# %%
data_novill['III_index_10000'].std()
# Out:
# 0.0

# %%
data_norm = (data - data.mean()) / data.std()

# %%
x_train, x_test, y_train, y_test = train_test_split( data_novill_norm, train_y , train_size = 0.8)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
from sklearn.svm import SVC
clf = SVC(gamma='auto')
clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-7f70a75dca9f> in <module>
#       1 from sklearn.svm import SVC
#       2 clf = SVC(gamma='auto')
# ----> 3 clf.fit(x_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         X, y = check_X_y(X, y, dtype=np.float64,
#     148                          order='C', accept_sparse='csr',
# --> 149                          accept_large_sparse=False)
#     150         y = self._validate_targets(y)
#     151
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
# ...

# %%
x_train
# Out:
#        III_1000  III_10000   III_250    III_50   III_500  III_5000   III_MIN  \
# 6792   1.301759   1.601474  0.986280  0.493051  1.012833  1.651674 -0.505904
# 56490 -1.189892  -0.512057 -0.998404 -0.460393 -1.173907 -0.473915  2.648313
# 45314 -0.274989   0.681985 -0.809386 -0.460393 -0.861516 -0.004468  0.281359
# 20268 -0.829770   1.145551 -0.998404 -0.460393 -0.955233  0.615725  0.559167
# 26809  2.177730   1.533865  1.553333 -0.460393  2.262398  1.499551 -0.423450
# 18512  1.953871   1.758740  1.269807 -0.460393  1.481420  2.483187 -0.245393
# 11186  2.479454   1.730226  1.931368  6.213714  2.074963  2.268425 -0.626271
# 1863  -0.362586   0.420072 -0.998404 -0.460393 -0.892755 -0.396132  0.523971
# 6743  -1.063363  -1.069688 -0.998404 -0.460393 -1.048951 -1.107874  0.532080
# 51915 -0.703241  -0.801602 -0.147825 -0.460393 -0.424168 -1.050054 -0.061095
# 26712  0.649648   1.053837  0.513737 -0.460393  0.669202  0.159357 -0.446007
# ...

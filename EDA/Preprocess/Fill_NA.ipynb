# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly 
#plotly.tools.set_credentials_file(username='jeff20628m', api_key='dGTlRhRtyDCAfsfoOE0u')

# %%
## Load data from dataset


data = pd.read_csv('C:\\Users\\USER\\github\\E.sun_conpetition\\data_set\\train.csv')

# %%
## collect all columns names to a list
columnslist = data.columns.tolist()

## check the len is right (same as data)

len(columnslist)
# Out:
# 235

# %% [markdown]
# ### columns [ 9 ,10 , 11 , 17 ] 中包含缺失值
#
# ### 可以查看columns的屬性並且觀看其填補缺失值方式

# %%
print(columnslist[9])
print(columnslist[10])
print(columnslist[11])
print(columnslist[17])
# Out:
# parking_area
# parking_price
# txn_floor
# village_income_median

# %% [markdown]
# ## Assume
#
# ### parking_area , parking_price 缺失值為 0轉換的結果  ， 所以我們以最小值在小一些來替代
#
# ### txn_floor   以最小值更小的值來替代
#
# ### village_income_median 刪除

# %% [markdown]
# # parking_area

# %%
data[columnslist[9]].describe()
# Out:
# count    3103.000000
# mean        7.211837
# std        20.453902
# min         0.000000
# 25%         3.738412
# 50%         5.758023
# 75%         7.180619
# max       967.370868
# Name: parking_area, dtype: float64

# %%
data[columnslist[9]].fillna(0,inplace = True)

# %%
data[columnslist[9]].describe()
# Out:
# count    60000.000000
# mean         0.372972
# std          4.917360
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        967.370868
# Name: parking_area, dtype: float64

# %% [markdown]
# ### 由於缺失值太多 若之後預測效果不好可能考慮直接刪除

# %% [markdown]
# # parking_price

# %%
data[columnslist[10]].describe()
# Out:
# count    1.393500e+04
# mean     5.025058e+04
# std      3.973488e+04
# min      0.000000e+00
# 25%      2.827238e+04
# 50%      4.379195e+04
# 75%      6.148857e+04
# max      1.020404e+06
# Name: parking_price, dtype: float64

# %%
data[columnslist[10]].fillna(0,inplace = True)

# %%
data[columnslist[10]].describe()
# Out:
# count    6.000000e+04
# mean     1.167070e+04
# std      2.858202e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.020404e+06
# Name: parking_price, dtype: float64

# %% [markdown]
# # txn_floor  粗估是樓層 所以我們已0.5層來代替NA值

# %%
data[columnslist[11]].describe()
# Out:
# count    44098.000000
# mean         5.389269
# std          3.944618
# min          1.000000
# 25%          3.000000
# 50%          4.000000
# 75%          7.000000
# max         28.000000
# Name: txn_floor, dtype: float64

# %%
data[columnslist[11]].fillna(0.5,inplace = True)

# %%
data[columnslist[11]].describe()
# Out:
# count    60000.000000
# mean         4.093450
# std          4.011553
# min          0.500000
# 25%          0.500000
# 50%          3.000000
# 75%          6.000000
# max         28.000000
# Name: txn_floor, dtype: float64

# %% [markdown]
# # village_income_median  暫時先刪除

# %%
data[columnslist[17]].describe()
# Out:
# count    58858.000000
# mean       674.840175
# std        140.653083
# min        411.000000
# 25%        583.000000
# 50%        642.000000
# 75%        729.000000
# max       1851.000000
# Name: village_income_median, dtype: float64

# %%
data_clean = data.dropna(axis=0)

# %%
data_clean
# Out:
#             building_id  building_material  city  txn_dt  total_floor  \
# 0      e3mMIMR3JJqCaXz1                  8    21   18674            4
# 1      LgwzgklNvy4QCtq5                  8     7   18800            5
# 2      ucIR2NLLsC3T650L                  8     7   19289            4
# 3      jre1pJhcQj91Kdky                  8    21   20385           24
# 4      rQpYpY9nRG7X5mmr                  1    21   20657            2
# 5      HmW2MkrwafmceWAH                  8    21   18394            5
# 6      ITYyim3zx6DQyCoF                  8     7   20474           15
# 7      KFrxqaWZaLynrOae                  8    12   18185            8
# 8      ZiK0gY7A0BvwZ8OV                  8    21   18794            5
# 9      QnytA7FbgaVxIDuP                  8     7   19927           10
# 10     jcbuA8q3KPH9SzpS                  1     7   18333            2
# 11     KHo10f3pvTcVL7Dc                  8    21   18184            5
# ...
